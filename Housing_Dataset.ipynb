# %%
# Import the libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Reading the data
df = pd.read_csv('HousingData.csv')

# %%
# Looking at the first 10 rows of the data
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87   NaN  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87   NaN  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %% [markdown]
# # Info about features:
#
#  CRIM: Per capita crime rate by town
#
#  ZN: Proportion of residential land zoned for lots over 25,000 sq. ft
#
#  INDUS: Proportion of non-retail business acres per town
#
#  CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#
#  NOX: Nitric oxide concentration (parts per 10 million)
#
#  RM: Average number of rooms per dwelling
#
#  AGE: Proportion of owner-occupied units built prior to 1940
#
#  DIS: Weighted distances to five Boston employment centers
#
#  RAD: Index of accessibility to radial highways
#
#  TAX: Full-value property tax rate per $10,000
#
#  PTRATIO: Pupil-teacher ratio by town
#
#  B: 1000(Bk — 0.63)², where Bk is the proportion of [people of African American descent] by town
#
#  LSTAT: Percentage of lower status of the population
#
#  MEDV: Median value of owner-occupied homes in $1000s

# %%
# Shape of the dataset
df.shape
# Out:
# (506, 14)

# %%
# Data type of each column(feature)
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
# Counting the number of null values present in each column
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560262   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#Visualizing the data (histogram)
df.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000266A370BE20>,
# ...
#       dtype=object)

# %%
# Visulaize the correlation
plt.figure(figsize = (10,10))
sns.heatmap(df.iloc[:,:].corr(), annot= True, fmt ='.0%')

# %%
#Visualizing the data by making density plot for each feature
for k,v in df.items():
    plt.figure(figsize=(5,4))
    sns.kdeplot(data = v, shade=True)

# %%
# Plotting a scatter plot for RM and MEDV
plt.figure(figsize=(12,6))
sns.scatterplot(x= df['RM'], y= df['MEDV'])

# %%
# Imputing the values  
from sklearn.impute import SimpleImputer

imp = SimpleImputer(strategy = 'most_frequent')
imp_1 = SimpleImputer(strategy = 'constant', fill_value=0)
imp_2 = SimpleImputer(strategy = 'mean')

df['CHAS'] = imp.fit_transform(df.loc[:,['CHAS']])

df['ZN'] = imp_1.fit_transform(df.loc[:,['ZN']])
df['CRIM'] = imp_1.fit_transform(df.loc[:,['CRIM']])

df['INDUS'] = imp_2.fit_transform(df.loc[:,['INDUS']])
df['AGE'] = imp_2.fit_transform(df.loc[:,['AGE']])
df['LSTAT'] = imp_2.fit_transform(df.loc[:,['LSTAT']])

# %%
#Removing the outliers
df = df[(~(df['MEDV']>=50))]
df = df[(df['RM'] >=4) & (~(df['RM'] >8.7))]

# %%
#Plotting a scatter plot for RM and MEDV after removing outliers
plt.figure(figsize=(12,6))
sns.scatterplot(x= df['RM'], y= df['MEDV'])

# %%
# New shape of the dataset
df.shape
# Out:
# (487, 14)

# %%
# Split the dataset into independent(X) and dependent(Y) datasets
X= df.iloc[:,0:13].values
Y= df.iloc[:,13].values

# %%
# Split the dataset into 70% training and 30% testing
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.30, random_state = 42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (340, 13)
# (147, 13)
# (340,)
# (147,)

# %%
# Creating models:
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import BayesianRidge
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn import metrics


# LINEAR REGRESSION:
lr = LinearRegression()
model = lr.fit(X_train,Y_train)
pred = model.predict(X_test)
lr_r2 = metrics.r2_score(Y_test, pred)
print('1. R2 score for Linear Regression: {:.4f}\n'.format(lr_r2))


# LASSO REGRESSION MODEL:
las = Lasso(alpha=0.01)
model1 = las.fit(X_train,Y_train)
pred1 = model1.predict(X_test)
las_r2 = metrics.r2_score(Y_test, pred1)
print('2. R2 score for Lasso Regression: {:.4f}\n'.format(las_r2))


# RIDGE REGRESSION:
ridge = Ridge()
ridge.fit(X_train,Y_train)
pred2 = ridge.predict(X_test)
ridge_r2 = metrics.r2_score(Y_test, pred2)
print('3. R2 score for Ridge Regression: {:.4f}\n'.format(ridge_r2))


# BAYESIANRIDGE REGRESSION:
br = BayesianRidge()
br.fit(X_train, Y_train)
pred3 = br.predict(X_test)
br_r2 = metrics.r2_score(Y_test, pred3)
print('4. R2 score for BayesianRidge Regression: {:.4f}\n'.format(br_r2))


# DECISION TREE REGRESSOR:
tr = tree.DecisionTreeRegressor(max_depth=5, criterion ='mae', random_state=42)
# predefined train and test sets
tr.fit(X_train, Y_train)
pred4 = tr.predict(X_test)
tr_r2 = metrics.r2_score(Y_test, pred4)
print('5. R2 score for Decision Tree Regressor: {:.4f}\n'.format(tr_r2))


#XGBoost Regressor:
xgb = XGBRegressor()
xgb.fit(X_train, Y_train)
pred5 = xgb.predict(X_test)
xgb_r2 = metrics.r2_score(Y_test, pred5)
print('6. R2 score for XGBoost Regressor: {:.4f}\n'.format(xgb_r2))


# RANDOM FOREST REGRESSOR:
rf = RandomForestRegressor(n_estimators = 100 , criterion='mae', max_depth=15, random_state=42)
rf.fit(X_train, Y_train)
pred6 = rf.predict(X_test)
rf_r2 = metrics.r2_score(Y_test, pred6)
print('7. R2 score for Random Forest Regressor: {:.4f}\n'.format(rf_r2))
# Out:
# 1. R2 score for Linear Regression: 0.8119
#
# 2. R2 score for Lasso Regression: 0.8117
#
# 3. R2 score for Ridge Regression: 0.8113
#
# 4. R2 score for BayesianRidge Regression: 0.8048
#
# 5. R2 score for Decision Tree Regressor: 0.8238
#
# 6. R2 score for XGBoost Regressor: 0.8878
#
# 7. R2 score for Random Forest Regressor: 0.8913
